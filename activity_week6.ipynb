# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\Vimal\Desktop\DAS\activity week 6\Dataset_w6.xlsx")

# %%
df.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia              652864
# 1              Albania  SouthernEurope               28748
# 2              Algeria  NorthernAfrica             2381741
# 3               Angola    MiddleAfrica             1246700
# 4  Antigua and Barbuda       Caribbean                 442
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530                         623.2
# 1                            2930                        3984.2
# 2                           41318                        4154.1
# 3                           29784                        4714.1
# 4                             102                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                             125                                        3568
# ...

# %%
df.isnull().sum()
# Out:
# country                                       0
# Region                                        0
# Surface area (km2)                            0
# Population in thousands (2017)                0
# GDP per capita (current US$)                  0
# Agricultural production index                 0
# International trade: Imports (million US$)    0
# dtype: int64

# %% [markdown]
# # Find out how many countries are there in the dataset

# %%
df.country
# Out:
# 0                             Afghanistan
# 1                                 Albania
# 2                                 Algeria
# 3                                  Angola
# 4                     Antigua and Barbuda
#                       ...
# 191    Venezuela (Bolivarian Republic of)
# 192                              Viet Nam
# 193                                 Yemen
# 194                                Zambia
# 195                              Zimbabwe
# Name: country, Length: 196, dtype: object

# %%
df.country.count()
# Out:
# 196

# %% [markdown]
# 196 country's in the data set

# %%
plt.figure(figsize=(15,15))
l=df['Region'].value_counts()
l
# Out:
# WesternAsia          18
# EasternAfrica        17
# Caribbean            16
# WesternAfrica        15
# SouthernEurope       12
# SouthAmerica         12
# South-easternAsia    11
# EasternEurope        10
# NorthernEurope       10
# SouthernAsia          9
# MiddleAfrica          9
# CentralAmerica        8
# EasternAsia           7
# WesternEurope         7
# CentralAsia           5
# NorthernAfrica        5
# Melanesia             5
# SouthernAfrica        5
# Polynesia             5
# NorthernAmerica       4
# Micronesia            4
# Oceania               2
# Name: Region, dtype: int64

# %% [markdown]
# # Examine the data by using visualizations

# %%
plt.figure(figsize=(720,720))
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Find out how many countries with respect to the region are available in the dataset

# %%
Re=df.groupby("Region").size().reset_index(name="Count")
Re
# Out:
#                Region  Count
# 0           Caribbean     16
# 1      CentralAmerica      8
# 2         CentralAsia      5
# 3       EasternAfrica     17
# 4         EasternAsia      7
# 5       EasternEurope     10
# 6           Melanesia      5
# 7          Micronesia      4
# 8        MiddleAfrica      9
# 9      NorthernAfrica      5
# 10    NorthernAmerica      4
# 11     NorthernEurope     10
# 12            Oceania      2
# 13          Polynesia      5
# 14  South-easternAsia     11
# 15       SouthAmerica     12
# 16     SouthernAfrica      5
# 17       SouthernAsia      9
# 18     SouthernEurope     12
# 19      WesternAfrica     15
# 20        WesternAsia     18
# 21      WesternEurope      7

# %%
plt.figure(figsize=(20,15))
plt.bar(Re["Region"],Re["Count"],)
plt.xticks(rotation ='vertical')
plt.show()

# %% [markdown]
# # On average which region has the highest a. GDP per capita (current US$)

# %%
gd=df.groupby("Region").mean()
gd
# Out:
#                    Surface area (km2)  Population in thousands (2017)  \
# Region
# Caribbean                1.375231e+04                     2431.187500
# CentralAmerica           3.108195e+05                    22164.750000
# CentralAsia              8.009040e+05                    14167.800000
# EasternAfrica            3.747603e+05                    24019.411765
# EasternAsia              1.680572e+06                   232076.857143
# EasternEurope            1.882619e+06                    29245.500000
# Melanesia                1.081544e+05                     2064.000000
# Micronesia               5.170000e+02                       74.250000
# MiddleAfrica             7.347640e+05                    18166.111111
# NorthernAfrica           1.134020e+06                    38503.600000
# NorthernAmerica          5.496082e+06                    90300.250000
# NorthernEurope           1.796507e+05                    10390.200000
# ...

# %%
Gdmx=gd.nlargest(1,"GDP per capita (current US$)")
Gdmx
# Out:
#                  Surface area (km2)  Population in thousands (2017)  \
# Region
# NorthernAmerica           5496081.5                        90300.25
#
#                  GDP per capita (current US$)  Agricultural production index   \
# Region
# NorthernAmerica                       57659.0                           108.5
#
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %% [markdown]
# NorthernAmerica has highest GDP per capita

# %% [markdown]
# # On average which region has the highest International trade: Imports (million US$)

# %%
Int=gd.nlargest(1,"International trade: Imports (million US$)")
Int
# Out:
#                  Surface area (km2)  Population in thousands (2017)  \
# Region
# NorthernAmerica           5496081.5                        90300.25
#
#                  GDP per capita (current US$)  Agricultural production index   \
# Region
# NorthernAmerica                       57659.0                           108.5
#
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %% [markdown]
# NorthernAmerica has highest International trade

# %% [markdown]
# # Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
cn=df.groupby("Region")["GDP per capita (current US$)"].describe()
cn
# Out:
#                    count          mean           std      min        25%  \
# Region
# Caribbean           16.0  15135.562500  14579.371326    793.7   6973.125
# CentralAmerica       8.0   6348.137500   4180.440883   2086.9   3558.100
# CentralAsia          5.0   4329.880000   4152.215490    925.9   1106.400
# EasternAfrica       17.0   2088.852941   3716.131770    144.5    529.200
# EasternAsia          7.0  27967.614286  27485.120923    648.0   6041.250
# EasternEurope       10.0   9292.490000   5415.488739   1591.4   6024.800
# Melanesia            5.0   9261.960000  13855.842686   1841.6   2783.000
# Micronesia           4.0   5008.300000   4820.669694   1442.9   2622.125
# MiddleAfrica         9.0   3928.833333   5274.846281    333.2    713.000
# NorthernAfrica       5.0   3934.960000    974.706575   2919.3   3452.300
# NorthernAmerica      4.0  57659.000000  25749.619445  36976.7  41648.375
# NorthernEurope      10.0  42098.220000  20671.030185  13704.1  23371.025
# ...

# %%
Mcn=cn.nsmallest(5,"std")
Mcn
# Out:
#                 count         mean          std     min     25%     50%  \
# Region
# WesternAfrica    15.0  1013.140000   815.095399   359.0   544.7   703.9
# NorthernAfrica    5.0  3934.960000   974.706575  2919.3  3452.3  3660.9
# SouthernAfrica    5.0  4191.900000  2177.551120   940.6  3211.7  4673.6
# SouthernAsia      9.0  2968.400000  2855.708179   623.2  1207.9  1614.2
# EasternAfrica    17.0  2088.852941  3716.131770   144.5   529.2   877.3
#
#                     75%      max
# Region
# WesternAfrica   1068.05   3080.2
# NorthernAfrica  4154.10   5488.2
# SouthernAfrica  5773.00   6360.6
# SouthernAsia    3973.70   9446.5
# EasternAfrica   1368.90  14133.2

# %% [markdown]
# WesternAfrica has lowest std. based on standerd deviation we can say that WesternAfrica has more consistent with respect to GDP
